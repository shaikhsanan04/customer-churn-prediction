# %% [markdown]
# # Telco Customer Churn Prediction - End-to-End Machine Learning Project
#
# ## Project Objective
# The goal of this project is to build and evaluate machine learning models
# to predict customer churn. We will:
#
# - Perform data preprocessing
# - Build ML pipelines
# - Train multiple classification models
# - Evaluate performance using confusion matrix, classification report, ROC-AUC
# - Tune decision threshold
# - Interpret feature importance
#
# This notebook follows a structured ML workflow suitable for portfolio presentation.

# %% [markdown]
# ---
# # 1. Data Loading & Initial Exploration
#
# In this section, we:
# - Load the dataset
# - Inspect structure
# - Check data types
# - Identify missing values
# - Understand class imbalance

# %% [markdown]
# ---
# # 2. Data Preprocessing
#
# We perform:
# - Train/Test split
# - Numerical pipeline (Median Imputation + Scaling)
# - Categorical pipeline (Encoding)
# - ColumnTransformer integration
# - Full ML pipeline creation
#
# Using pipelines ensures:
# - No data leakage
# - Clean reproducible workflow
# - Production-ready structure

# %% [markdown]
# ---
# # 3. Model Training & Evaluation
#
# Models tested:
# - Logistic Regression
# - Random Forest
# - Gradient Boosting
#
# Evaluation metrics used:
# - Confusion Matrix
# - Precision
# - Recall
# - F1 Score
# - Accuracy

# %% [raw]
# 1. define the problem
#
# Problem Type - Supervised Learning
# Task - Binary Classification
# Target Variable - Churn
# Goal - Predict which customer will leave
#
# Why we do this:
#
# Because ML is not about code first.
# It’s about defining what we’re solving.
#
# If you don’t define:
#
# What is X?
#
# What is y?
#
# What is success?
#
# You’re just coding randomly.

# %% [raw]
# 2. Load and Understand the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit

# %%
data = pd.read_csv('C:/Users/sanan/Downloads/telco customer/Telco-Customer-Churn.csv')
df = data.copy()

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.sample(25)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 248   0322-YINQP    Male              0      No         No       1
# 623   5148-HKFIR  Female              0      No         No      20
# 5960  2957-JIRMN  Female              1      No         No      62
# 6278  7208-PSIHR  Female              0     Yes         No      70
# 5358  6082-GLJIX    Male              0      No         No      18
# 3357  3891-PUQOD  Female              0      No        Yes       1
# 6177  1260-TTRXI    Male              0      No         No       4
# 4473  2665-NPTGL  Female              1     Yes         No      26
# 1432  9046-DQMTP    Male              0      No         No      35
# 2590  4526-ZJJTM  Female              1     Yes         No      25
# 5858  8241-JUIQO  Female              0      No         No      61
# 105   6180-YBIQI    Male              0      No         No       5
# 1056  6941-PMGEP  Female              0      No         No       5
# ...

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [raw]
# 3. Check Class Distribution (VERY IMPORTANT)
#
# Why:
#
# If dataset is imbalanced (like 80% No, 20% Yes),
# random splitting can destroy class proportion.
#
# And if that happens:
# Your model evaluation becomes misleading.
#
# This is why stratification matters.

# %%
df['Churn'].value_counts(normalize = True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %% [raw]
# 4. Create Stratified Train-Test Split
#
# Instead of simple train_test_split, use:
# StratifiedShuffleSplit
#
# What it does:
# It ensures both train and test sets have:
# Same percentage of churners
# Same percentage of non-churners
#
# Why we use it:
# Because in classification, class imbalance matters.
#
# If:
#
# Train set has 30% churn
# Test set has 10% churn
# Your model will behave unpredictably.
# Stratification keeps distribution consistent.
# This is data discipline.

# %%
og_split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 42)

for train_index, test_index in og_split.split(df, df['Churn']):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %% [raw]
# Small Check (Very Important)
# They should be very close to original distribution.

# %%
strat_train_set['Churn'].value_counts(normalize = True)
# Out:
# Churn
# No     0.734647
# Yes    0.265353
# Name: proportion, dtype: float64

# %%
strat_test_set['Churn'].value_counts(normalize = True)
# Out:
# Churn
# No     0.734564
# Yes    0.265436
# Name: proportion, dtype: float64

# %% [raw]
# 5. Separate Features and Target
#
# Why:
# Models need:
#
# X → input features
# y → output label
#
# Clear separation avoids mistakes later.

# %%
x_train = strat_train_set.drop('Churn', axis = 1)
y_train = strat_train_set['Churn']

x_test = strat_test_set.drop('Churn', axis = 1)
y_test = strat_test_set['Churn']

# %% [raw]
# 6. Explore the Training Data (Not Test Data)
#
# Important rule from your PDF:
# Never explore test data deeply.
#
# Why:
#
# If you analyze test data too much,
# you leak information.
#
# That causes overfitting in evaluation.
#
# Always explore only training data.

# %%
x_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5634 entries, 3738 to 5639
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5634 non-null   str
#  1   gender            5634 non-null   str
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   str
#  4   Dependents        5634 non-null   str
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   str
#  7   MultipleLines     5634 non-null   str
#  8   InternetService   5634 non-null   str
#  9   OnlineSecurity    5634 non-null   str
#  10  OnlineBackup      5634 non-null   str
#  11  DeviceProtection  5634 non-null   str
#  12  TechSupport       5634 non-null   str
#  13  StreamingTV       5634 non-null   str
#  14  StreamingMovies   5634 non-null   str
#  15  Contract          5634 non-null   str
#  16  PaperlessBilling  5634 non-null   str
# ...

# %% [raw]
# Data Preparation Pipeline
#
# Now the serious part.
#
# You likely have:
#
# Numerical columns (Tenure, MonthlyCharges)
#
# Categorical columns (Contract, PaymentMethod)
#
# You must:
#
# Scale numerical features
#
# One-hot encode categorical features
#
# Use:
#
# ColumnTransformer
#
# Pipeline
#
# Why use Pipeline?
#
# Because:
#
# Keeps preprocessing consistent
#
# Avoids data leakage
#
# Makes project production-ready
#
# Without pipeline, your code becomes messy and unsafe.

# %%
# Dropping customerID because its just an identifier and has zero predicitve value

x_train.drop('customerID', axis = 1, inplace = True)

# %%
# converting TotalCharges column from str to numeric in x_train and x_test

x_train['TotalCharges'] = pd.to_numeric(x_train['TotalCharges'], errors = 'coerce')
x_test['TotalCharges'] = pd.to_numeric(x_test['TotalCharges'], errors = 'coerce')

# %%
# creating num_cols and cat_cols

num_cols = ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

cat_cols = ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']


# Why This Is Professional Practice

# Because:
# It prevents applying scaling to categorical columns.
# It prevents one-hot encoding numeric columns.
# It keeps everything organized.
# It avoids data leakage.

# %% [raw]
# now lets fill median values from train data to both x_train and x_test
#
# Because if you calculate median using test data,
# you are leaking future information into training process.
#
# That makes evaluation dishonest.

# %% [raw]
# not the correct approach for ML models instead use a simple imputer
#
# median_value = x_train['TotalCharges'].median()
#
# x_train["TotalCharges"] = x_train["TotalCharges"].fillna(median_value)
# x_test["TotalCharges"] = x_test["TotalCharges"].fillna(median_value)
#
# The problem with this approach is :
#
# ❌ Problem 1: Data Leakage Risk
# If you calculate median using full dataset before splitting,
# you leak information from test set.
#
# That makes evaluation dishonest.
#
#
# ❌ Problem 2: Not Scalable
# If later you deploy model in production,
# you don’t want to manually calculate medians every time.
#
# You want preprocessing to be part of the model.
# That’s why we use SimpleImputer inside a pipeline.
#
# 🎯 Why SimpleImputer Is Better
# SimpleImputer:
# Learns median from training data only
# Stores that value internally
# Applies same value to test data
# Becomes part of ML pipeline
# Prevents data leakage
# Works automatically during prediction
# This is professional ML practice.
#
# 📌 Where To Use It?
#
# Inside your numeric preprocessing pipeline.
# Not before splitting.
# Never before splitting.
#
# 🧱 Step-by-Step Correct Way
# You already have:
# X_train
# X_test
#
# And you have:
# num_cols
# cat_cols
#
# Now you build preprocessing.
#
# 🔢 Numeric Pipeline
# For numeric columns:
#
# You usually do:
# Impute missing values
# Scale data
#
# So numeric pipeline becomes:

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ('imputer' , SimpleImputer(strategy = 'median')),
    ('scaler' , StandardScaler())
])

# %%
# Handling categorical columns

# For categorical columns, you usually:
# Impute missing values (most frequent)
# One-hot encode

from sklearn.preprocessing import OneHotEncoder

cat_pipeline = Pipeline([
    ('imputer' , SimpleImputer(strategy = 'most_frequent')),
    ('encoder' , OneHotEncoder(handle_unknown = 'ignore'))
])

# %% [raw]
# Why handle_unknown='ignore'?
#
# Because if test data contains a category not seen during training,
# the model won’t crash.
#
# Very important for production mindset.

# %% [raw]
# Combine Both Pipelines Using ColumnTransformer

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer([
    ('num', num_pipeline, num_cols),
    ('cat', cat_pipeline, cat_cols)
])

# %% [raw]
# Build Final ML Pipeline

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Logistic Regression

full_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('model', LogisticRegression())
])

# Now everything is inside one pipeline.

# %%
# Train Model
full_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['SeniorCitizen', 'tenure',
#                                                    'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
# ...

# %%
# make predictions
y_pred = full_pipeline.predict(x_test)

# It will:

# Automatically preprocess X_test

# Apply scaling and encoding using training statistics

# Feed transformed data into Logistic Regression

# Return predictions

# You do NOT manually preprocess test data.

# Pipeline handles everything.

# That’s why pipelines are powerful.

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = full_pipeline.predict(x_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[926 109]
#  [165 209]]
#               precision    recall  f1-score   support
#
#           No       0.85      0.89      0.87      1035
#          Yes       0.66      0.56      0.60       374
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
LogisticRegression(class_weight="balanced")
# Out:
# LogisticRegression(class_weight='balanced')

# %%
new_full_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('model', LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %%
new_full_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['SeniorCitizen', 'tenure',
#                                                    'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
# ...

# %%
y_pred_new = new_full_pipeline.predict(x_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[926 109]
#  [165 209]]
#               precision    recall  f1-score   support
#
#           No       0.85      0.89      0.87      1035
#          Yes       0.66      0.56      0.60       374
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
from sklearn.ensemble import RandomForestClassifier

full_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('model', RandomForestClassifier(random_state=42))
])

# %%
full_pipeline.fit(x_train, y_train)
y_pred = full_pipeline.predict(x_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[918 117]
#  [196 178]]
#               precision    recall  f1-score   support
#
#           No       0.82      0.89      0.85      1035
#          Yes       0.60      0.48      0.53       374
#
#     accuracy                           0.78      1409
#    macro avg       0.71      0.68      0.69      1409
# weighted avg       0.77      0.78      0.77      1409

# %%
from sklearn.ensemble import GradientBoostingClassifier

full_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('model', GradientBoostingClassifier(random_state = 42))
])

full_pipeline.fit(x_train, y_train)

y_pred = full_pipeline.predict(x_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[940  95]
#  [178 196]]
#               precision    recall  f1-score   support
#
#           No       0.84      0.91      0.87      1035
#          Yes       0.67      0.52      0.59       374
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.72      0.73      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
full_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('model', LogisticRegression())
])

full_pipeline.fit(x_train, y_train)

y_prob = full_pipeline.predict_proba(x_test)[:, 1]


y_pred_custom = np.where(y_prob > 0.4, "Yes", "No")

print(confusion_matrix(y_test, y_pred_custom))
print(classification_report(y_test, y_pred_custom))
# Out:
# [[846 189]
#  [124 250]]
#               precision    recall  f1-score   support
#
#           No       0.87      0.82      0.84      1035
#          Yes       0.57      0.67      0.62       374
#
#     accuracy                           0.78      1409
#    macro avg       0.72      0.74      0.73      1409
# weighted avg       0.79      0.78      0.78      1409

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get probabilities for positive class (churn = 1)
y_prob = full_pipeline.predict_proba(x_test)[:, 1]

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label='Yes')

# Compute AUC score
auc_score = roc_auc_score(y_test, y_prob)

# Plot
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {auc_score:.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Get feature names after preprocessing
feature_names = full_pipeline.named_steps["preprocessing"].get_feature_names_out()

# Get model coefficients
coefficients = full_pipeline.named_steps["model"].coef_[0]

# Create dataframe
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": coefficients
})

# Sort by absolute importance
importance_df["abs_coef"] = np.abs(importance_df["Coefficient"])
importance_df = importance_df.sort_values("abs_coef", ascending=False).head(10)

# Plot
plt.figure(figsize=(8, 6))
plt.barh(importance_df["Feature"], importance_df["Coefficient"])
plt.xlabel("Coefficient Value")
plt.title("Top 10 Important Features")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ---
# # 4. ROC Curve & AUC
#
# ROC Curve shows how well the model separates churn vs non-churn
# across different probability thresholds.
#
# - AUC closer to 1 → Strong model
# - AUC around 0.5 → Random guessing

# %% [markdown]
# ---
# # 5. Feature Importance
#
# For Logistic Regression:
# - Coefficients indicate impact direction
# - Positive → increases churn probability
# - Negative → reduces churn probability
# - Larger magnitude → stronger effect
#
# This helps translate ML results into business insight.

# %% [markdown]
# ---
# # 6. Conclusion
#
# Final Observations:
# - Compared multiple models
# - Tuned threshold for better recall/precision tradeoff
# - Evaluated using ROC-AUC
# - Identified key churn drivers
#
# This notebook demonstrates a complete binary classification workflow
# from preprocessing to business interpretation.
